# %%
pip install langchain langchain-groq

# %%
# Define the model to use
LLAMA_MODEL = "llama-3.3-70b-versatile"

# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq
load_dotenv()

llm = ChatGroq(
    model=LLAMA_MODEL,
    temperature=0.7
)

def simple_chat_without_memory(user_query):
    response = llm.invoke(user_query)
    return response.content

# %%
respone1= simple_chat_without_memory("I want to learn AI")
print(respone1)
# Out:
# That's a great goal. Artificial Intelligence (AI) is a fascinating field that's rapidly evolving and has numerous applications across various industries. To get started, here's a suggested learning path:
#
# **Prerequisites:**
#
# 1. **Mathematics:** Linear Algebra, Calculus, Probability, and Statistics are essential math concepts for AI.
# 2. **Programming:** Python is the most popular language used in AI, so having a good grasp of Python programming is crucial.
# 3. **Data Structures and Algorithms:** Familiarity with data structures like arrays, linked lists, stacks, queues, and algorithms like sorting, searching, and graph traversal is necessary.
#
# **Learning Resources:**
#
# 1. **Online Courses:**
# 	* Andrew Ng's Machine Learning course on Coursera
# 	* Stanford University's Natural Language Processing with Deep Learning Specialization on Coursera
# 	* MIT OpenCourseWare: Introduction to Computer Science and Programming in Python
# 2. **Books:**
# 	* "Deep Learning" by Ian Goodfellow, Yoshua Bengio, and Aaron Courville
# 	* "Pattern Recognition and Machine Learning" by Christopher Bishop
# 	* "Python Machine Learning" by Sebastian Raschka
# 3. **Practice:**
# 	* Kaggle: A platform for machine learning competitions and hosting datasets
# 	* TensorFlow or PyTorch: Popular open-source machine learning libraries
# 	* Scikit-learn: A Python library for machine learning
#
# **AI Subfields:**
#
# 1. **Machine Learning (ML):** Focuses on developing algorithms that enable computers to learn from data.
# 2. **Deep Learning (DL):** A subset of ML that uses neural networks to analyze data.
# 3. **Natural Language Processing (NLP):** Deals with the interaction between computers and humans in natural language.
# 4. **Computer Vision:** Concerned with enabling computers to interpret and understand visual data from images and videos.
#
# **Tips:**
#
# 1. **Start with the basics:** Ensure you have a solid grasp of math, programming, and data structures before diving into AI.
# 2. **Practice consistently:** Work on projects and participate in competitions to apply your knowledge and improve your skills.
# 3. **Stay updated:** Follow AI research, blogs, and news to stay current with the latest developments and advancements.
# 4. **Join online communities:** Engage with online forums, such as Reddit's r/MachineLearning and r/AI, to connect with other learners and experts.
#
# Remember, learning AI is a continuous process. Be patient, persistent, and enjoy the journey!

# %%
respone2= simple_chat_without_memory("Can you give me a learning plan")
print(respone1)
# Out:
# That's a great goal. Artificial Intelligence (AI) is a fascinating field that's rapidly evolving and has numerous applications across various industries. To get started, here's a suggested learning path:
#
# **Prerequisites:**
#
# 1. **Mathematics:** Linear Algebra, Calculus, Probability, and Statistics are essential math concepts for AI.
# 2. **Programming:** Python is the most popular language used in AI, so having a good grasp of Python programming is crucial.
# 3. **Data Structures and Algorithms:** Familiarity with data structures like arrays, linked lists, stacks, queues, and algorithms like sorting, searching, and graph traversal is necessary.
#
# **Learning Resources:**
#
# 1. **Online Courses:**
# 	* Andrew Ng's Machine Learning course on Coursera
# 	* Stanford University's Natural Language Processing with Deep Learning Specialization on Coursera
# 	* MIT OpenCourseWare: Introduction to Computer Science and Programming in Python
# 2. **Books:**
# 	* "Deep Learning" by Ian Goodfellow, Yoshua Bengio, and Aaron Courville
# 	* "Pattern Recognition and Machine Learning" by Christopher Bishop
# 	* "Python Machine Learning" by Sebastian Raschka
# 3. **Practice:**
# 	* Kaggle: A platform for machine learning competitions and hosting datasets
# 	* TensorFlow or PyTorch: Popular open-source machine learning libraries
# 	* Scikit-learn: A Python library for machine learning
#
# **AI Subfields:**
#
# 1. **Machine Learning (ML):** Focuses on developing algorithms that enable computers to learn from data.
# 2. **Deep Learning (DL):** A subset of ML that uses neural networks to analyze data.
# 3. **Natural Language Processing (NLP):** Deals with the interaction between computers and humans in natural language.
# 4. **Computer Vision:** Concerned with enabling computers to interpret and understand visual data from images and videos.
#
# **Tips:**
#
# 1. **Start with the basics:** Ensure you have a solid grasp of math, programming, and data structures before diving into AI.
# 2. **Practice consistently:** Work on projects and participate in competitions to apply your knowledge and improve your skills.
# 3. **Stay updated:** Follow AI research, blogs, and news to stay current with the latest developments and advancements.
# 4. **Join online communities:** Engage with online forums, such as Reddit's r/MachineLearning and r/AI, to connect with other learners and experts.
#
# Remember, learning AI is a continuous process. Be patient, persistent, and enjoy the journey!
